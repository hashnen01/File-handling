# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#
# Interpreted Language:-
#
# Executes line by line	.
#
# Slower execution.
#
# Easier debugging.
#
# Example: Python.
#
# Compiled Language:-
#
# Entire code compiled first.
#
# Faster execution.
#
# Harder debugging.
#
# Example: C, C++

# %% [markdown]
# 2. What is exception handling in Python?
#
# Answer:
#
# Exception handling is a mechanism used to handle runtime errors without stopping program execution.
#
# Keywords:
#
# try,
# except,
# else,
# finally.

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling?
#
# Answer:
#
# The finally block executes whether an exception occurs or not.

# %% [markdown]
# 4. What is logging in Python?
#
# Answer:
#
# Logging is the process of recording events, warnings, errors, and debugging information during program execution.
#
# Python provides the logging module for this purpose.

# %% [markdown]
# 5. What is the significance of the __del__() method in Python?
#
# Answer:
#
# __del__() is called when an object is about to be destroyed.
#
# It is known as the destructor.

# %% [markdown]
# **6. What is the difference between import and from ... import**?
#
# Answer:
#
# import math
#
# Access using:
#
# math.sqrt(25)
# from math import sqrt
#
# Access using:
#
# sqrt(25)
#
# Difference: from...import imports specific functions, whereas import imports the entire module.
#
# **7. How can you handle multiple exceptions in Python** ?
#
# Answer:
#
# Using multiple except blocks.
#
# try:
#
#     x = int(input())
#
# except ValueError:
#
#     print("Invalid Input")
#
# except ZeroDivisionError:
#
#     print("Division Error")

# %% [markdown]
# 8. What is the purpose of the with statement when handling files?
#
# Answer:
#
# The with statement automatically closes the file after use.
#
# Example:
#
# with open("file.txt","r") as f:
#     data = f.read()
#
# No need to call close() manually.

# %% [markdown]
# 9. What is the difference between multithreading and multiprocessing?
#
#
# Multithreading:-
#
# Multiple threads.
#
# Shared memory	.
#
# Lightweight	.
#
# Better for I/O tasks.
#
# Multiprocessing:-
#
# Multiple processes.
#
# Separate memory.
#
# Heavyweight.
#
# Better for CPU tasks.

# %% [markdown]
# **10. What are the advantages of using logging in a program**?
#
# Answer:
#
# Tracks errors.
#
# Helps debugging..
#
# Maintains execution history.
#
# Improves monitoring.
#
# **11. What is memory management in Python**?
#
# Answer:
#
# Memory management is the process of allocating and releasing memory during program execution.
#
# Python automatically manages memory using:
#
# Reference Counting.
#
# Garbage Collection.
#
# **12. What are the basic steps involved in exception handling**?
#
# Answer:
#
# Place risky code inside try.
# Catch exceptions using except.
# Use else for successful execution.
# Use finally for cleanup.
#
# **13. Why is memory management important in Python**?
#
# Answer:
#
# Prevents memory leaks
# Improves performance
# Optimizes resource usage
# Maintains system stability
#
#
# 14. What is the role of try and except in exception handling **bold text**?
#
# Answer:
#
# try
#
# Contains code that may generate an exception.
#
# except
#
# Handles the exception and prevents program termination.
#
# **15. How does Python's garbage collection system work**?
#
# Answer:
#
# Python automatically removes unused objects from memory.
#
# It uses:
#
# Reference Counting
# Garbage Collector (gc module)
#
# This frees memory occupied by unused objects.

# %% [markdown]
# **16. What is the purpose of the else block in exception handling**?
#
# Answer:
#
# The else block executes only if no exception occurs.
#
# Example:
#
# try:
#
#     x = 10/2
#
# except:
#
#     print("Error")
#
# else:
#
#     print("Success")
#
# 17.** What are the common logging levels in Python** ?
#
# Answer:
#
# Level:-
#
# DEBUG.
#
# INFO.
#
# WARNING.
#
# ERROR	.
#
# CRITICAL.
#
# Purpose:-
#
# Detailed information.
#
# General information.
#
# Warning messages.
#
# Error messages.
#
# Serious errors.
#
# 18.** What is the difference between os.fork() and multiprocessing in Python**?
#
# Answer:
#
# os.fork():-
#
# Available mainly on Unix/Linux.
#
# Creates a child process.
#
# multiprocessing:-
#
# Cross-platform.
#
# Easier to use.
#
# Recommended in Python.
#
# 19. **What is the importance of closing a file in Python**?
#
# Answer:
#
# Closing a file:
#
# Saves changes.
#
# Releases memory.
#
# Prevents corruption.
#
# Frees system resources.

# %% [markdown]
# 20. **What is the difference between file.read() and file.readline(**)?
#
# read():-
#
# Reads entire file	.
#
# Returns full content.
#
# readline():-
#
# Reads one line.
#
# Returns single line.

# %% [markdown]
# 21.** What is the logging module in Python used for?
#
# Answer:
#
# The logging module records events, warnings, errors, and debugging information during program execution.

# %% [markdown]
# 22. **What is the os module in Python used for file handling**?
#
# Answer:
#
# The os module provides functions to interact with files and directories.
#
# Examples:
#
# import os
#
# os.remove("file.txt")
#
# os.rename("a.txt","b.txt")

# %% [markdown]
# 23. **What are the challenges associated with memory management in Python**?
#
# Answer:
#
# Memory leaks.
#
# Circular references.
#
# High memory consumption.
#
# Performance overhead.
#
# 24.** How do you raise an exception manually in Python**?
#
# Answer:
#
# Using the raise keyword.

# %% [markdown]
# 25. **Why is it important to use multithreading in certain applications**?
#
# Answer:
#
# Multithreading improves responsiveness and performance in I/O-bound applications such as:
#
# Web servers.
#
# File downloading.
#
# Network communication.
#
# GUI applications

# %% [markdown]
# **PRACTICAL QUESTION:-**

# %%
# Q1. How can you open a file for writing in Python and write a string to it?

file = open("sample.txt", "w")

file.write("Hello World")

file.close()

print("Data Written Successfully")
# Out:
# Data Written Successfully

# %%
# Q2. Write a Python program to read the contents of a file and print each line.

with open("sample.txt", "r") as file:

    for line in file:
        print(line.strip())
# Out:
# Hello World

# %%
# Q3. Handle the case where the file doesn't exist while reading.

try:

    file = open("abc.txt", "r")

    print(file.read())

except FileNotFoundError:

    print("File Not Found")
# Out:
# File Not Found

# %%
# Q4. Read from one file and write its content to another file.

with open("source.txt", "w") as file:
    file.write("Python Programming")

with open("source.txt", "r") as src:
    data = src.read()

with open("destination.txt", "w") as dest:
    dest.write(data)

print("File Copied Successfully")
# Out:
# File Copied Successfully

# %%
# Q5. Catch and handle division by zero error.

try:

    result = 10 / 0

except ZeroDivisionError:

    print("Cannot Divide By Zero")
# Out:
# Cannot Divide By Zero

# %%
# Q6. Log an error message when division by zero occurs.

import logging

logging.basicConfig(
    filename="error.log",
    level=logging.ERROR
)

try:

    result = 10 / 0

except ZeroDivisionError:

    logging.error("Division By Zero Error")

    print("Error Logged")
# Out:
# ERROR:root:Division By Zero Error
# Error Logged

# %%
# Q7. Log information at different levels.

import logging

logging.basicConfig(level=logging.DEBUG)

logging.info("Information Message")

logging.warning("Warning Message")

logging.error("Error Message")
# Out:
# WARNING:root:Warning Message
# ERROR:root:Error Message

# %%
# Q8. Handle a file opening error using exception handling.

try:

    file = open("xyz.txt", "r")

except Exception as e:

    print("Error:", e)
# Out:
# Error: [Errno 2] No such file or directory: 'xyz.txt'

# %%
# Q9. Read a file line by line and store it in a list.

with open("sample.txt", "r") as file:

    lines = file.readlines()

print(lines)
# Out:
# ['Hello World']

# %%
# Q10. Append data to an existing file.

with open("sample.txt", "a") as file:

    file.write("\nNew Data Added")

print("Data Appended")
# Out:
# Data Appended

# %%
# Q11. Handle error when accessing a dictionary key that doesn't exist.

student = {
    "name": "Hasnain"
}

try:

    print(student["age"])

except KeyError:

    print("Key Not Found")
# Out:
# Key Not Found

# %%
# Q12. Demonstrate multiple except blocks.

try:

    num = int(input("Enter Number: "))

    result = 10 / num

except ValueError:

    print("Invalid Input")

except ZeroDivisionError:

    print("Division By Zero")

except Exception:

    print("Other Error")
# Out:
# Enter Number: 123

# %%
# Q13. Check if a file exists before reading.

import os

if os.path.exists("sample.txt"):

    print("File Exists")

else:

    print("File Not Found")
# Out:
# File Exists

# %%
# Q14. Log informational and error messages.

import logging

logging.basicConfig(
    filename="app.log",
    level=logging.INFO
)

logging.info("Program Started")

logging.error("Sample Error Message")
# Out:
# ERROR:root:Sample Error Message

# %%
# Q15. Print file contents and handle empty file.

with open("sample.txt", "r") as file:

    data = file.read()

    if data == "":

        print("File Is Empty")

    else:

        print(data)
# Out:
# Hello World
# New Data Added

# %%
# Q16. Use memory profiling to check memory usage.

from sys import getsizeof

numbers = [1,2,3,4,5]

print(
    "Memory Used:",
    getsizeof(numbers),
    "bytes"
)
# Out:
# Memory Used: 104 bytes

# %%
# Q17. Create and write a list of numbers to a file.

with open("numbers.txt", "w") as file:

    for i in range(1,11):

        file.write(str(i) + "\n")

print("Numbers Written")
# Out:
# Numbers Written

# %%
# Q18. Basic logging setup with file rotation.

import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler(
    "app.log",
    maxBytes=1000000,
    backupCount=3
)

logger = logging.getLogger()

logger.setLevel(logging.INFO)

logger.addHandler(handler)

logger.info("Log Message")
# Out:
# INFO:root:Log Message

# %%
# Q19. Handle both IndexError and KeyError.

try:

    mylist = [10,20]

    print(mylist[5])

except IndexError:

    print("Index Error")

try:

    mydict = {"a":1}

    print(mydict["b"])

except KeyError:

    print("Key Error")
# Out:
# Index Error
# Key Error

# %%
# Q20. Open a file and read its contents using a context manager.

with open("sample.txt", "r") as file:

    data = file.read()

    print(data)
# Out:
# Hello World
# New Data Added

# %%
# Q21. Count occurrences of a specific word in a file.

with open("sample.txt", "w") as file:

    file.write("python python java python")

with open("sample.txt", "r") as file:

    text = file.read()

count = text.count("python")

print("Occurrences:", count)
# Out:
# Occurrences: 3

# %%
# Q22. Check if a file is empty.

import os

if os.path.getsize("sample.txt") == 0:

    print("File Is Empty")

else:

    print("File Has Data")
# Out:
# File Has Data

# %%
# Q23. Write to a log file when an error occurs during file handling.

import logging

logging.basicConfig(
    filename="error.log",
    level=logging.ERROR
)

try:

    file = open("missing.txt", "r")

except Exception as e:

    logging.error(str(e))

    print("Error Logged")
# Out:
# ERROR:root:[Errno 2] No such file or directory: 'missing.txt'
# Error Logged
